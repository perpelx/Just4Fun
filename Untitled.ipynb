# %%
import os
import glob

# %%
own_path = r'D:\VNPY\00.课件、代码、练习数据与参考资料\vnpy\vnpy-master_19'

# %%
path_tree = os.walk(own_path)

# %%
for dirName, subdirList, fileList in path_tree: 
    print('Folder: %s' % dirName) 
    for fname in fileList: 
        print('\t%s' % fname)
# Out:
# Folder: D:\VNPY\00.课件、代码、练习数据与参考资料\vnpy\vnpy-master_19
# 	.gitignore
# 	.travis.yml
# 	init.bat
# 	install.bat
# 	install.sh
# 	LICENSE
# 	mongod.cfg
# 	README-en.md
# 	README.md
# 	requirements.txt
# 	setup.py
# Folder: D:\VNPY\00.课件、代码、练习数据与参考资料\vnpy\vnpy-master_19\beta
# Folder: D:\VNPY\00.课件、代码、练习数据与参考资料\vnpy\vnpy-master_19\beta\api
# Folder: D:\VNPY\00.课件、代码、练习数据与参考资料\vnpy\vnpy-master_19\beta\api\coincheck
# 	README.txt
# 	test.html
# 	test.py
# 	test2.py
# 	test3.py
# 	test4.py
# 	vncoincheck.py
# 	__init__.py
# Folder: D:\VNPY\00.课件、代码、练习数据与参考资料\vnpy\vnpy-master_19\beta\api\korbit
# 	readme.txt
# 	run.bat
# 	test.py
# 	vnkorbit.py
# 	__init__.py
# Folder: D:\VNPY\00.课件、代码、练习数据与参考资料\vnpy\vnpy-master_19\beta\api\korbit\korbit-python-master
# 	.travis.yml
# 	LICENSE
# 	README.md
# 	setup.py
# Folder: D:\VNPY\00.课件、代码、练习数据与参考资料\vnpy\vnpy-master_19\beta\api\korbit\korbit-python-master\korbit
# 	private_api.py
# 	public_api.py
# 	test.py
# 	__init__.py
# ...
